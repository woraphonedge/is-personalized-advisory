# %%
import pandas as pd

# %%
df_es = pd.read_parquet("../app/data/portfolios_product_mapping_2025-10-31.parquet")

# %%
df_es.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322736 entries, 0 to 322735
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   product_id            322736 non-null  string
#  1   src_sharecodes        322736 non-null  string
#  2   desk                  322736 non-null  string
#  3   port_type             322736 non-null  string
#  4   currency              322736 non-null  string
#  5   product_display_name  320665 non-null  string
#  6   product_type_desc     322736 non-null  string
#  7   asset_class_name      322736 non-null  string
#  8   symbol                322736 non-null  string
#  9   pp_asset_sub_class    322736 non-null  string
#  10  is_risky_asset        322736 non-null  bool
#  11  coverage_prdtype      26486 non-null   string
#  12  is_coverage           322736 non-null  bool
#  13  expected_return       322736 non-null  float64
# ...

# %%
df_es.head().T
# Out:
#                                             0                         1  \
# product_id                          C00249664                 C00010907
# src_sharecodes        LB_FIX(620005390300011)   FD_3000196913_11(-0243)
# desk                                     LOAN                     TRADE
# port_type                                   S                         L
# currency                                  THB                       THB
# product_display_name             Lombard Loan           KK FD-CORPORATE
# product_type_desc                        Loan                      Cash
# asset_class_name                   Unassigned  Cash and Cash Equivalent
# symbol                LB_FIX(620005390300011)                      CASH
# pp_asset_sub_class                 Unassigned                  Cash THB
# is_risky_asset                           True                     False
# coverage_prdtype                         <NA>                      <NA>
# ...

# %%
df_es.query("product_id == 'C00142044'").T
# Out:
#                                                  290427
# product_id                                    C00142044
# src_sharecodes                            SS_2013096061
# desk                                              TRADE
# port_type                                             L
# currency                                            THB
# product_display_name  KKP Smart Settlement (Individual)
# product_type_desc                                  Cash
# asset_class_name               Cash and Cash Equivalent
# symbol                                             CASH
# pp_asset_sub_class                             Cash THB
# is_risky_asset                                    False
# coverage_prdtype                                   <NA>
# is_coverage                                        True
# expected_return                                    0.04
# es_core_port                                       True
# es_sell_list                                       <NA>
# ...

# %%
df_port = pd.read_parquet(
    "../app/data/portfolios_client_out_enriched_2025-10-31.parquet"
)

# %%
df_port.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405903 entries, 0 to 405902
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   customer_id           405903 non-null  int64
#  1   as_of_date            405903 non-null  datetime64[ns]
#  2   product_id            405903 non-null  object
#  3   src_sharecodes        405903 non-null  object
#  4   desk                  405903 non-null  object
#  5   port_type             405903 non-null  object
#  6   currency              405903 non-null  string
#  7   product_display_name  405834 non-null  string
#  8   product_type_desc     405903 non-null  string
#  9   asset_class_name      405903 non-null  string
#  10  symbol                405903 non-null  string
#  11  pp_asset_sub_class    405903 non-null  string
#  12  is_risky_asset        405903 non-null  bool
#  13  coverage_prdtype      235406 non-null  string
# ...

# %%
df_port.query("customer_id == 39597").T
# Out:
#                                    389106               394111  \
# customer_id                         39597                39597
# as_of_date            2025-10-31 00:00:00  2025-10-31 00:00:00
# product_id                      M00072598            M00248078
# src_sharecodes                 KFGBRAND-A       KKP EWUS500-UH
# desk                                TRADE                TRADE
# port_type                               L                    L
# currency                              THB                  THB
# product_display_name           KFGBRAND-A       KKP EWUS500-UH
# product_type_desc             Mutual Fund          Mutual Fund
# asset_class_name            Global Equity        Global Equity
# symbol                         KFGBRAND-A       KKP EWUS500-UH
# pp_asset_sub_class          Global Equity            US Equity
# is_risky_asset                       True                 True
# coverage_prdtype              MUTUAL_FUND          MUTUAL_FUND
# ...
