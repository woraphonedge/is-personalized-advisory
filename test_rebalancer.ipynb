# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings

from dotenv import load_dotenv

warnings.filterwarnings("ignore")

# %%
from app.utils.data_loader import DataLoader
from app.utils.health_score import HealthScore
from app.utils.portfolios import Portfolios
from app.utils.portfolios_repo import PortfoliosRepository
from app.utils.portfolios_service import PortfolioService
from app.utils.portprop_matrices import PortpropMatrices
from app.utils.portprop_matrices_repo import PortpropMatricesRepository
from app.utils.rebalancer import Rebalancer
from app.utils.rebalancer_repo import RebalancerRepository

# %% [markdown]
# ## Load Data

# %%
load_dotenv()  # Load environment variables from .env file
print(os.getenv('LOAD_DATA_FROM_DWH'))
# Out:
# false

# %%
data_loader=DataLoader()
ppm_repo = PortpropMatricesRepository(data_loader=data_loader)
ports_repo = PortfoliosRepository(data_loader=data_loader)
rebalancer_repo = RebalancerRepository(data_loader=data_loader)

# %%
client_out_enriched = ports_repo.load_client_out_product_enriched(
    as_of_date="2025-08-31"
)
client_styles = ports_repo.load_client_style(
    as_of_date="2025-08-31"
)

# %%
ports_ref_table = {
            'product_mapping' : ports_repo.load_product_mapping(),
            'product_underlying' : ports_repo.load_product_underlying(),
}

# %%
ppm_ref_dict = {
    "portprop_factsheet": ppm_repo.load_portprop_factsheet(),
    "portprop_benchmark": ppm_repo.load_portprop_benchmark(),
    "portprop_ge_mapping": ppm_repo.load_portprop_ge_mapping(),
    "portprop_fallback": ppm_repo.load_portprop_fallback(),
    "portprop_ret_eow": ppm_repo.load_portprop_ret_eow(),
    "advisory_health_score": ppm_repo.load_advisory_health_score(),
}

# %%
rb_ref_dict = {
    "es_sell_list": rebalancer_repo.load_es_sell_list(),
    "product_recommendation_rank_raw": rebalancer_repo.load_product_recommendation_rank_raw(),
    "mandate_allocation": rebalancer_repo.load_mandate_candidates(),
}

# %% [markdown]
# ## Instances

# %%
## Portsfolios
ports_all = Portfolios()
ports_all.set_ref_tables(ports_ref_table)
df_out, df_style, port_ids, port_id_mapping = ports_all.create_portfolio_id(client_out_enriched, client_styles, column_mapping=['as_of_date', 'customer_id'])
ports_all.set_portfolio(df_out, df_style, port_ids, port_id_mapping)

## Portfolio Service
port_service = PortfolioService(ports_all)

## Portprop Matrices
ppm = PortpropMatrices(ppm_ref_dict)

## Health Score
hs = HealthScore()

## Rebalancer
rb = Rebalancer()
rb.set_ref_tables(rb_ref_dict)

# %% [markdown]
# ## Portfolio (Service)

# %%
## get list of all customer ids
print(port_service.get_all_customer_ids())
# Out:
# [24149, 27766, 28359, 23349, 36170, 27144, 18051, 30961, 35258, 45708, 45701, 50745, 51637, 61749, 58055, 72106, 74374, 76048, 76011, 72660, 86279, 94903, 57414, 96146, 53015, 23905, 35261, 30030, 103542, 107010, 52747, 27547, 14154, 21427, 12346, 49474, 54552, 19583, 48844, 30174, 31843, 35059, 26925, 30084, 52903, 28587, 28508, 11838, 18550, 23356, 29901, 32263, 12883, 109086, 80627, 17739, 16906, 10052, 12001, 28999, 24287, 33624, 17533, 26352, 33901, 25512, 12594, 23791, 33516, 39036, 28624,
 73373, 74373, 74497, 79095, 32816, 33799, 84392, 82252, 88169, 90566, 57172, 98243, 99138, 33093, 22153, 87132, 39720, 28085, 109683, 112373, 103022, 84, 12287, 24715, 50651, 29721, 24294, 81671, 28031, 34055, 64106, 34654, 12798, 21040, 15617, 17348, 26160, 15642, 23814, 15646, 13623, 18999, 11736, 11701, 16988, 14055, 33221, 16454, 46246, 64421, 55063, 32647, 24926, 47830, 85695, 12237, 33456, 30857, 11277, 36277, 37324, 37928, 39155, 53233, 57014, 33892, 59308, 46927, 72100, 73312, 74528, 74319, 58926, 90716, 90267, 32135, 23029, 13403, 26048, 102260, 55365, 106624, 108182, 109142, 110856, 23221, 34936, 16320, 30812, 55522, 46900, 21516, 27337, 32229, 22363, 22578, 100493, 36417, 22599, 21148, 21022, 28994, 25693, 35638, 52822, 39151, 12172, 97204, 15559, 32557, 27739, 31685, 20218, 38095, 27075, 46122, 49223, 52327, 34428, 448 ...

# %%
## get single port from customer id
port = port_service.get_client_portfolio(customer_id=12560)

# %%
## get port outstanding
port.df_out
# Out:
#        customer_id as_of_date product_id  src_sharecodes   desk port_type  \
# 399          12560 2025-08-31  B00174068         NTL26NA  TRADE         L
# 400          12560 2025-08-31  B00174420         CPF23PA  TRADE         L
# 453          12560 2025-08-31  M00299362     KKP SIB-USD  TRADE         L
# 1375         12560 2025-08-31  B00138028        MINT23PA  TRADE         L
# 1379         12560 2025-08-31  B00164409       CPAXT289A  TRADE         L
# ...            ...        ...        ...             ...    ...       ...
# 18416        12560 2025-08-31  T00320952    XS3102117291    GIS         L
# 19216        12560 2025-08-31  B00221075         IVL24PA  TRADE         L
# 19219        12560 2025-08-31  B00304257    USY0616GAA14    GIS         L
# 19291        12560 2025-08-31  M00232288  KKP PGE RMF-UH  TRADE         L
# 19293        12560 2025-08-31  M00250758    LU2405385126    GIS         L
#
#       currency                               product_display_name  \
# 399        THB                                            NTL26NA
# 400        THB                                            CPF23PA
# 453        USD                                        KKP SIB-USD
# 1375       THB                                           MINT23PA
# 1379       THB                                          CPAXT289A
# ...        ...                                                ...
# 18416      USD                                     SHFIN20250630A
# 19216      THB                                            IVL24PA
# 19219      USD                         USY0616GAA14YQ4728834 corp
# 19291      THB                                     KKP PGE RMF-UH
# 19293      USD  GS JAPAN EQUITY PARTNERS PORTFOLIO "OCS" (USDH...
#
#       product_type_desc asset_class_name  ... is_coverage expected_return  \
# 399        Fixed Income     Fixed Income  ...        True           0.025
# 400        Fixed Income     Fixed Income  ...        True           0.025
# 453         Mutual Fund     Fixed Income  ...        True           0.048
# 1375       Fixed Income     Fixed Income  ...        True           0.025
# 1379       Fixed Income     Fixed Income  ...        True           0.025
# ...                 ...              ...  ...         ...             ...
# 18416   Structured Note    Global Equity  ...        True           0.077
# 19216      Fixed Income     Fixed Income  ...        True           0.025
# 19219      Fixed Income     Fixed Income  ...        True           0.025
# 19291       Mutual Fund    Global Equity  ...        True           0.077
# 19293       Mutual Fund    Global Equity  ...        True           0.077
#
#        es_core_port es_sell_list  flag_top_pick  flag_tax_saving  \
# 399           False         <NA>   Not Top-Pick             <NA>
# 400           False         <NA>   Not Top-Pick             <NA>
# 453           False         <NA>   Not Top-Pick             <NA>
# 1375          False         <NA>   Not Top-Pick             <NA>
# 1379          False         <NA>   Not Top-Pick             <NA>
# ...             ...          ...            ...              ...
# 18416         False         <NA>   Not Top-Pick             <NA>
# 19216         False         <NA>   Not Top-Pick             <NA>
# 19219         False         <NA>   Not Top-Pick             <NA>
# 19291         False         <NA>       Top-Pick              RMF
# 19293         False         <NA>       Top-Pick             <NA>
#
#               value port_id asset_class_code    weight
# 399    2.065495e+06    1147            AA_FI  0.012518
# 400    2.138060e+06    1147            AA_FI  0.012958
# 453    4.980829e+03    1147            AA_FI  0.000030
# 1375   4.133600e+06    1147            AA_FI  0.025052
# 1379   2.097467e+06    1147            AA_FI  0.012712
# ...             ...     ...              ...       ...
# 18416  1.599890e+06    1147            AA_GE  0.009696
# 19216  2.327808e+06    1147            AA_FI  0.014108
# 19219  6.560369e+06    1147            AA_FI  0.039759
# 19291  5.187173e+06    1147            AA_GE  0.031437
# 19293  1.735213e+05    1147            AA_GE  0.001052
#
# [76 rows x 24 columns]

# %%
# get port allocation lookthrough
port.get_portfolio_asset_allocation_lookthrough(ppm)
# Out:
# asset_class  port_id    aa_alt   aa_cash     aa_fi     aa_ge     aa_le
# 0               1147  0.060932  0.041909  0.400828  0.390025  0.106306

# %%
# get model allocation 
port.get_model_asset_allocation_lookthrough(ppm)
# Out:
#    port_id port_investment_style                portpop_styles  aa_alt_model  \
# 0     1147    Moderate High Risk  Medium to Moderate High Risk          0.13
#
#    aa_cash_model  aa_fi_model  aa_ge_model  aa_le_model
# 0           0.06         0.27         0.45         0.05

# %% [markdown]
# ## Healthscore

# %%
## get client health score
health_score, health_score_comp = port.get_portfolio_health_score(ppm,hs)

# %%
health_score['health_score'].values[0]
# Out:
# np.float64(8.0)

# %% [markdown]
# ## Rebalancer

# %%
rb.rebalance(port, ppm, hs)
# Out:
#   transaction_no batch_no port_id    product_id  src_sharecodes   desk  \
# 0              1        1    1147     S00087551          BTSGIF  TRADE
# 1              2        1    1147  CTHB00000000  Cash Proxy THB  TRADE
# 2              3        2    1147     S00237377           VAYU1  TRADE
# 3              4        2    1147  CTHB00000000  Cash Proxy THB  TRADE
# 4              5        3    1147  DTHB00000000    KKPBAPLUSTHB  TRADE
# 5              6        3    1147  CTHB00000000  Cash Proxy THB  TRADE
#
#   port_type currency       value    weight                   flag  \
# 0         L      THB   3545000.0  0.021485  not_monitored_product
# 1         L      THB         NaN       NaN     cash_proxy_funding
# 2         L      THB  15900000.0  0.096362  not_monitored_product
# 3         L      THB         NaN       NaN     cash_proxy_funding
# 4         L      THB         0.0  0.000000      discretionary_buy
# 5         L      THB         NaN       NaN     cash_proxy_funding
#
#    expected_weight   action        amount
# 0         0.000000     sell -3.545000e+06
# 1              NaN  funding  3.545000e+06
# 2         0.000000     sell -1.590000e+07
# 3              NaN  funding  1.590000e+07
# 4         0.090553      buy  1.494139e+07
# 5              NaN  funding -1.494139e+07

# %%
port.df_out
# Out:
#     port_id product_id src_sharecodes   desk port_type currency         value  \
# 0      1147  B00138028       MINT23PA  TRADE         L      THB  4.133600e+06
# 1      1147  B00138680        TUC282A  TRADE         L      THB  2.026721e+06
# 2      1147  B00143744      BGRIM23PA  TRADE         L      THB  2.099210e+06
# 3      1147  B00145295     LOTUSS284A  TRADE         L      THB  3.194455e+06
# 4      1147  B00151378       SIRI25DA  TRADE         L      THB  2.004395e+06
# ..      ...        ...            ...    ...       ...      ...           ...
# 70     1147  T00281178   XS3004384742    GIS         L      USD  9.804772e+05
# 71     1147  T00305836   XS2993068878    GIS         L      USD  2.617949e+06
# 72     1147  T00310048   XS3048279049    GIS         L      USD  1.927777e+06
# 73     1147  T00320952   XS3102117291    GIS         L      USD  1.599890e+06
# 74     1147  T00321173   XS3102102939    GIS         L      USD  1.615964e+06
#
#    product_display_name product_type_desc asset_class_name  ...  \
# 0              MINT23PA      Fixed Income     Fixed Income  ...
# 1               TUC282A      Fixed Income     Fixed Income  ...
# 2             BGRIM23PA      Fixed Income     Fixed Income  ...
# 3            LOTUSS284A      Fixed Income     Fixed Income  ...
# 4              SIRI25DA      Fixed Income     Fixed Income  ...
# ..                  ...               ...              ...  ...
# 70       SHFIN20250221A   Structured Note    Global Equity  ...
# 71       SHFIN20250401A   Structured Note    Global Equity  ...
# 72       SHFIN20250428A   Structured Note    Global Equity  ...
# 73       SHFIN20250630A   Structured Note    Global Equity  ...
# 74        ATCL20250701F   Structured Note    Global Equity  ...
#
#    is_risky_asset coverage_prdtype  is_coverage expected_return  es_core_port  \
# 0            True              N/A         True           0.025         False
# 1            True              N/A         True           0.025         False
# 2            True              N/A         True           0.025         False
# 3            True              N/A         True           0.025         False
# 4            True              N/A         True           0.040         False
# ..            ...              ...          ...             ...           ...
# 70           True              N/A         True           0.077         False
# 71           True              N/A         True           0.077         False
# 72           True              N/A         True           0.077         False
# 73           True              N/A         True           0.077         False
# 74           True              N/A         True           0.077         False
#
#     es_sell_list  flag_top_pick flag_tax_saving asset_class_code    weight
# 0           <NA>   Not Top-Pick            <NA>            AA_FI  0.025052
# 1           <NA>   Not Top-Pick            <NA>            AA_FI  0.012283
# 2           <NA>   Not Top-Pick            <NA>            AA_FI  0.012722
# 3           <NA>   Not Top-Pick            <NA>            AA_FI  0.019360
# 4           <NA>   Not Top-Pick            <NA>            AA_FI  0.012148
# ..           ...            ...             ...              ...       ...
# 70          <NA>   Not Top-Pick            <NA>            AA_GE  0.005942
# 71          <NA>   Not Top-Pick            <NA>            AA_GE  0.015866
# 72          <NA>   Not Top-Pick            <NA>            AA_GE  0.011683
# 73          <NA>   Not Top-Pick            <NA>            AA_GE  0.009696
# 74          <NA>   Not Top-Pick            <NA>            AA_GE  0.009794
#
# [75 rows x 22 columns]
